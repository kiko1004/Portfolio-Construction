# %%
import os
os.getcwd()
os.chdir("C:\\Users\\kiril\\Desktop\\WD\\Python\\")

# %%
import pandas as pd
data = pd.read_csv("data/edhec-hedgefundindices.csv",
                       header=0, index_col=0, na_values=-99.99)

# %%
data = data/100
data
# Out:
#             Convertible Arbitrage  CTA Global  Distressed Securities  \
# date
# 31/01/1997                 0.0119      0.0393                 0.0178
# 28/02/1997                 0.0123      0.0298                 0.0122
# 31/03/1997                 0.0078     -0.0021                -0.0012
# 30/04/1997                 0.0086     -0.0170                 0.0030
# 31/05/1997                 0.0156     -0.0015                 0.0233
# ...                           ...         ...                    ...
# 31/07/2018                 0.0021     -0.0058                 0.0093
# 31/08/2018                 0.0024      0.0166                 0.0002
# 30/09/2018                 0.0034     -0.0054                 0.0050
# 31/10/2018                -0.0073     -0.0314                -0.0158
# 30/11/2018                -0.0068     -0.0053                -0.0193
#
#             Emerging Markets  Equity Market Neutral  Event Driven  \
# date
# ...

# %%
data.index = pd.to_datetime(data.index)
data.index = data.index.to_period('M')

# %%
data
# Out:
#          Convertible Arbitrage  CTA Global  Distressed Securities  \
# date
# 1997-01                 0.0119      0.0393                 0.0178
# 1997-02                 0.0123      0.0298                 0.0122
# 1997-03                 0.0078     -0.0021                -0.0012
# 1997-04                 0.0086     -0.0170                 0.0030
# 1997-05                 0.0156     -0.0015                 0.0233
# ...                        ...         ...                    ...
# 2018-07                 0.0021     -0.0058                 0.0093
# 2018-08                 0.0024      0.0166                 0.0002
# 2018-09                 0.0034     -0.0054                 0.0050
# 2018-10                -0.0073     -0.0314                -0.0158
# 2018-11                -0.0068     -0.0053                -0.0193
#
#          Emerging Markets  Equity Market Neutral  Event Driven  \
# date
# 1997-01            0.0791                 0.0189        0.0213
# ...

# %%
erk.var_gaussian(data['2000':]['Distressed Securities'], 1, modified = True)*100
# Out:
# 4.966909110627918

# %%
erk.var_historic(data['2000':]['Distressed Securities'], 1)*100
# Out:
# 4.2642

# %%
l = ['Books', 'Steel', 'Oil', 'Mines']

# %%
ind[l]
cov = ind[l].cov()

# %%
cov
# Out:
#           Books     Steel       Oil     Mines
# Books  0.005119  0.004300  0.002562  0.002813
# Steel  0.004300  0.007106  0.003512  0.004408
# Oil    0.002562  0.003512  0.003713  0.002809
# Mines  0.002813  0.004408  0.002809  0.005304

# %%
newCov
# Out:
#           Books     Steel       Oil     Mines
# Books  0.002799  0.002098  0.002558  0.001629
# Steel  0.002098  0.004027  0.003473  0.001843
# Oil    0.002558  0.003473  0.005296  0.001961
# Mines  0.001629  0.001843  0.001961  0.002059

# %%
erk.get_portfolios(er[l], cov, riskfree_rate=0.1)
# Out:
# MSR portfolio is:
#          0
# Books  0.0
# Steel  1.0
# Oil    0.0
# Mines  0.0
# GMV protfolio is:
#            0
# Books  0.254
# Steel  0.000
# Oil    0.566
# Mines  0.180
# EW portfolio is:
#           0
# Books  0.25
# Steel  0.25
# Oil    0.25
# Mines  0.25

# %%
erk.gmv(cov)
# Out:
# array([2.54436876e-01, 2.12015735e-15, 5.66042915e-01, 1.79520210e-01])

# %%
gmv_weights = erk.gmv(cov.loc[l, l])
gmv_weights
print(gmv_weights.max(), l[gmv_weights.argmax()])
# Out:
# 0.5660429146740471 Oil

# %%
newCov = ind['2018'][l].cov()

# %%
newCov
# Out:
#           Books     Steel       Oil     Mines
# Books  0.002799  0.002098  0.002558  0.001629
# Steel  0.002098  0.004027  0.003473  0.001843
# Oil    0.002558  0.003473  0.005296  0.001961
# Mines  0.001629  0.001843  0.001961  0.002059

# %%
import numpy as np

# %%
msr_weig = np.array([0,1,0,0])
gmv_weig = np.array([0.254,0,0.566,0.18])

# %%
msr_vol = erk.portfolio_vol(msr_weig,newCov)
gmv_vol = erk.portfolio_vol(gmv_weig,newCov)

# %%
msr_vol*100
# Out:
# 6.346230747220723

# %%
erk.annualize_vol_compiled(msr_vol,12)*100
# Out:
# 21.983988181484186

# %%
gmv_vol*100
# Out:
# 5.681404483255932

# %%
# Out:
# 5.681404483255932

# %%
ind['2018'][l]
# Out:
#           Books   Steel     Oil   Mines
# 2018-01  0.0449  0.0361  0.0286  0.0357
# 2018-02 -0.0325 -0.0199 -0.1102 -0.0335
# 2018-03  0.0031 -0.0586  0.0308 -0.0015
# 2018-04 -0.0062  0.0366  0.1030 -0.0339
# 2018-05 -0.0061  0.0562  0.0343  0.0308
# 2018-06  0.0218 -0.0514  0.0052 -0.0178
# 2018-07 -0.0417  0.0424  0.0104 -0.0224
# 2018-08 -0.0447 -0.0323 -0.0295 -0.1075
# 2018-09 -0.0221 -0.0067  0.0356 -0.0173
# 2018-10 -0.0666 -0.1161 -0.1206 -0.1032
# 2018-11  0.0325 -0.0300 -0.0233 -0.0095
# 2018-12 -0.1535 -0.1478 -0.1325 -0.0706

# %%
erk.annualize_vol_using_ret(ind['2018'][l],12)
# Out:
# Books    0.183266
# Steel    0.219840
# Oil      0.252093
# Mines    0.157180
# dtype: float64
